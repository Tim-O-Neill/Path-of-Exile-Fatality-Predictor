# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Path_of_Exile_Endless_Delve_SSF_HC_DE002_league_export.22_Mar_18.08_03_39.1.csv')
df2 = pd.read_csv('Path_of_Exile_SSF_Expedition_HC_league_export.22_Mar_18.08_03_27.1.csv')
df3 = pd.read_csv('Path_of_Exile_SSF_Ritual_HC_league_export.22_Mar_18.08_03_52.1.csv')
df4 = pd.read_csv('Path_of_Exile_SSF_Ultimatum_HC_league_export.22_Mar_18.08_03_10.1.csv')
df5 = pd.read_csv('EndlessDelveDepth.csv')

# %%
df1.head()
# Out:
#    Rank         Account           Character       Class  Level  Experience  \
# 0     1  TooLegitToQuit  ToucanMiningOpsLLC    Champion     99  3932831405
# 1     2        ryzenier    ㅏtwitchtvㆍhsdffㅓ   Gladiator     99  3932818530
# 2     3          marvyu           PadoruApe    Saboteur     99  3932818530
# 3     4          Aveen_           AvnDugDig  Hierophant     98  3761329358
# 4     5        evanloaf   DelveIsNotPoggies   Occultist     98  3725527527
#
#    Dead
# 0   NaN
# 1  Dead
# 2  Dead
# 3  Dead
# 4   NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1345 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
df1['Account'].unique()
# Out:
# array(['TooLegitToQuit', 'ryzenier', 'marvyu', ..., 'Palmernick22',
#        'JerseyShore', 'Omenapoe'], dtype=object)

# %%
df5.head()
# Out:
#    Rank         Account           Character       Class  Level  Experience  \
# 0     1  TooLegitToQuit  ToucanMiningOpsLLC    Champion     99  3932831405
# 1     2        ryzenier    ㅏtwitchtvㆍhsdffㅓ   Gladiator     99  3932818530
# 2     3          marvyu           PadoruApe    Saboteur     99  3932818530
# 3     4          Aveen_           AvnDugDig  Hierophant     98  3761329358
# 4     5        evanloaf   DelveIsNotPoggies   Occultist     98  3725527527
#
#    Dead
# 0   NaN
# 1  Dead
# 2  Dead
# 3  Dead
# 4   NaN

# %%
len(df5['Account'].unique())
# Out:
# 1708

# %%
df4.tail()
# Out:
#       Rank        Account                Character        Class  Level  \
# 1995  1996     Griffinpoe  SpellCuckToChampEnjoyer     Champion     93
# 1996  1997  HachcomBabaow        HachcomBonkBabaow    Berserker     93
# 1997  1998        puffenk              ColtaineTTT  Necromancer     93
# 1998  1999     Wånderlust         NextGauntletWhen       Raider     93
# 1999  2000       nimoniku          GEDOUSAMAFANBOY     Saboteur     93
#
#       Experience  Dead
# 1995  2557847065  Dead
# 1996  2557554402  Dead
# 1997  2557025145  Dead
# 1998  2556398054  Dead
# 1999  2556352847  Dead

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1485 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
df2.describe()
# Out:
#               Rank        Level    Experience
# count  2000.000000  2000.000000  2.000000e+03
# mean   1000.500000    94.395000  2.857447e+09
# std     577.494589     1.920369  4.448986e+08
# min       1.000000    92.000000  2.357910e+09
# 25%     500.750000    93.000000  2.512468e+09
# 50%    1000.500000    94.000000  2.724612e+09
# 75%    1500.250000    95.000000  3.076226e+09
# max    2000.000000   100.000000  4.250334e+09

# %%
df3.head(30)
# Out:
#     Rank     Account                Character         Class  Level  \
# 0      1   Steelmage               SteelSadge      Champion    100
# 1      2       Unt12        OttersGottaVortex     Occultist    100
# 2      3   Cruzeriox         Cruz_BuffBoomkin     Trickster    100
# 3      4    rami1337  Omega๏Monatsblutug๏Rami     Gladiator    100
# 4      5  wuchermann    DARKHOLESTHREECINDERs     Gladiator    100
# 5      6       Cynic        SteelmageNoticeMe     Gladiator    100
# 6      7    weilingz     MichiritualShinohera     Trickster    100
# 7      8      CBYHEP          VIDEODRIVERTEST   Necromancer    100
# 8      9     SymDonB     SymChieftainIsBoring   Necromancer    100
# 9     10  vk41k32006                 Cardoude     Occultist    100
# 10    11    lalagate     Lalagate_SkinnyFists     Berserker    100
# 11    12     da_mike                 damikeEQ     Gladiator    100
# 12    13    offchops             chop_rituals      Champion    100
# ...

# %%
df3[df3['Time in seconds'] > 0]
# Out:
#       Rank      Account             Character        Class  Level  \
# 0        1    Steelmage            SteelSadge     Champion    100
# 6        7     weilingz  MichiritualShinohera    Trickster    100
# 7        8       CBYHEP       VIDEODRIVERTEST  Necromancer    100
# 8        9      SymDonB  SymChieftainIsBoring  Necromancer    100
# 12      13     offchops          chop_rituals     Champion    100
# ...    ...          ...                   ...          ...    ...
# 1620  1621     Walenaxx      enoughhhhhhhhhhh     Champion     95
# 1648  1649     Mirkheim      BFBBInquisRitual   Inquisitor     95
# 1712  1713     Quantrik     Quantrik_TotemGod     Champion     95
# 1851  1852  Robotmaxboy     SlammingOnYourMom       Slayer     95
# 1938  1939    lee840914                un_AMD    Gladiator     95
#
#       Time in seconds  Experience  Dead
# 0          1611662959  4250334444  Dead
# 6          1611372250  4250334444   NaN
# 7          1611089767  4250334444   NaN
# ...

# %%
df3.describe()
# Out:
#               Rank       Level  Time in seconds    Experience
# count  2000.000000  2000.00000     2.000000e+03  2.000000e+03
# mean   1000.500000    96.70250     2.194879e+08  3.402200e+09
# std     577.494589     1.56851     5.533590e+08  4.057277e+08
# min       1.000000    95.00000     0.000000e+00  2.909487e+09
# 25%     500.750000    95.00000     0.000000e+00  3.065653e+09
# 50%    1000.500000    96.00000     0.000000e+00  3.291935e+09
# 75%    1500.250000    98.00000     0.000000e+00  3.665905e+09
# max    2000.000000   100.00000     1.618203e+09  4.250334e+09

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             2000 non-null   int64
#  1   Account          2000 non-null   object
#  2   Character        2000 non-null   object
#  3   Class            2000 non-null   object
#  4   Level            2000 non-null   int64
#  5   Time in seconds  2000 non-null   int64
#  6   Experience       2000 non-null   int64
#  7   Dead             1402 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 125.1+ KB

# %%
df4.head()
# Out:
#    Rank         Account                Character      Class  Level  \
# 0     1       Towerbrah        premiumㆍTowerbrah  Gladiator    100
# 1     2    KuschelKatze    HimikoDDHaveMercyOnMe  Trickster    100
# 2     3        rami1337  ๛Rami๛Futa๛Harem๛Haram๛   Guardian    100
# 3     4      EverAnimal               Stillworld  Trickster    100
# 4     5  Inexorable_PoE                      ㆍ_ㆍ  Trickster    100
#
#    Experience  Dead
# 0  4250334444   NaN
# 1  4250334444  Dead
# 2  4250334444   NaN
# 3  4250334444  Dead
# 4  4250334444   NaN

# %%
df4.describe()
# Out:
#               Rank        Level    Experience
# count  2000.000000  2000.000000  2.000000e+03
# mean   1000.500000    95.274500  3.052237e+09
# std     577.494589     1.802158  4.380732e+08
# min       1.000000    93.000000  2.556353e+09
# 25%     500.750000    94.000000  2.717813e+09
# 50%    1000.500000    95.000000  2.914769e+09
# 75%    1500.250000    96.000000  3.260854e+09
# max    2000.000000   100.000000  4.250334e+09

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1478 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1345 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1485 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             2000 non-null   int64
#  1   Account          2000 non-null   object
#  2   Character        2000 non-null   object
#  3   Class            2000 non-null   object
#  4   Level            2000 non-null   int64
#  5   Time in seconds  2000 non-null   int64
#  6   Experience       2000 non-null   int64
#  7   Dead             1402 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 125.1+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1478 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2000 non-null   int64
#  1   Account     2000 non-null   object
#  2   Character   2000 non-null   object
#  3   Class       2000 non-null   object
#  4   Level       2000 non-null   int64
#  5   Experience  2000 non-null   int64
#  6   Dead        1345 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB
